# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# %matplotlib inline

df = pd.read_csv("/content/drive/MyDrive/Chandini/USA Housing Dataset.csv")
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-09 00:00:00   376000.0       3.0       2.00         1340      1384
# 1  2014-05-09 00:00:00   800000.0       4.0       3.25         3540    159430
# 2  2014-05-09 00:00:00  2238888.0       5.0       6.50         7270    130017
# 3  2014-05-09 00:00:00   324000.0       3.0       2.25          998       904
# 4  2014-05-10 00:00:00   549900.0       5.0       2.75         3060      7015
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     3.0           0     0          3        1340              0      2008
# 1     2.0           0     0          3        3540              0      2007
# 2     2.0           0     0          3        6420            850      2010
# 3     2.0           0     0          3         798            200      2007
# 4     1.0           0     0          5        1600           1460      1979
#
# ...

# %%
x = df.iloc[:, 2:-1]  # All rows, columns from index 2 to the second last
y = df.iloc[:, 1]     # All rows, column at index 1

# %%
x.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0       3.0       2.00         1340      1384     3.0           0     0
# 1       4.0       3.25         3540    159430     2.0           0     0
# 2       5.0       6.50         7270    130017     2.0           0     0
# 3       3.0       2.25          998       904     2.0           0     0
# 4       5.0       2.75         3060      7015     1.0           0     0
#
#    condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3        1340              0      2008             0
# 1          3        3540              0      2007             0
# 2          3        6420            850      2010             0
# 3          3         798            200      2007             0
# 4          5        1600           1460      1979             0
#
#                     street       city  statezip
# 0  9245-9249 Fremont Ave N    Seattle  WA 98103
# 1         33001 NE 24th St  Carnation  WA 98014
# ...

# %%
# Identify categorical columns
categorical_features = ['street','city', 'statezip']

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
# Create column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ],
    remainder='passthrough'  # leave other columns unchanged
)

# %%
# Create a pipeline with preprocessing and linear regression
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((2773, 15), (2773,), (1367, 15), (1367,))

# %%
from sklearn.preprocessing import StandardScaler
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/compose/_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['street', 'city',
#                                                    'statezip'])])),
# ...

# %%
y_pred=model.predict(x_test)

# %%
print(f"R2 Score on Test Data: {r2_score(y_test, y_pred):.2f}")
# Out:
# R2 Score on Test Data: 0.55

# %%
import numpy as np

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# 64757777574.99458
# 146488.59033434498
# 254475.49503831324

# %%
def predict_price(input_data):
    """
    Predicts the house price for a new data input.
    input_data: dictionary with keys matching feature names.
    """
    input_df = pd.DataFrame([input_data])
    estimated_price = model.predict(input_df)
    return estimated_price[0]

# %%
new_house = {
    'bedrooms': 3,
    'bathrooms': 2,
    'street': '123 Main St Apt 4B',
    'sqft_living': 2000,
    'sqft_lot': 5000,
    'floors': 1,
    'waterfront': 0,
    'view': 2,
    'condition': 4,
    'sqft_above': 1800,
    'sqft_basement': 200,
    'yr_built': 2010,
    'yr_renovated': 2015,
    'city': 'Seattle',
    'statezip': 'WA 98103'
}

# %%
# Predict price
predicted_price = predict_price(new_house)
print(f"Estimated Price for the New House: ${predicted_price:,.2f}")
# Out:
# Estimated Price for the New House: $826,436.30
